# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
new_data = np.arange(9)

# %%
# %matplotlib notebook

# %%
# %matplotlib inline

# %%
plt.plot(new_data)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.title("The new data graph")
# Out:
# Text(0.5, 1.0, 'The new data graph')

# %%
plt.xlabel("x label name")
# Out:
# Text(0.5, 36.283333333333324, 'x label name')

# %%
plt.ylabel("y label name")
# Out:
# Text(83.83333333333334, 0.5, 'y label name')

# %%
x = [1, 2, 3, 4, 5, 6, 7]
y = [1, 4, 9, 16, 25, 36, 49]

# %%
plt.plot(x, y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data1 = np.arange(2, 7, 0.3)

# %%
plt.plot(data1, data1, "r--", data1, data1**2, "bs", data1, data1**3, "g^")
# Out:
# <img src="data:image/png;base64,..." width="640">
# [<matplotlib.lines.Line2D at 0x24dbf2b2ee0>,
#  <matplotlib.lines.Line2D at 0x24dbf2b2d00>,
#  <matplotlib.lines.Line2D at 0x24dbf2b2f10>]

# %%
plt.savefig("newvisualize.png")

# %%
new_films = ["film1", "film2", "film3", "film4"]
awards = [3, 9, 1, 5]

# %%
plt.bar(range(len(new_films)), awards)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 4 artists>

# %%
plt.title("The top films")
# Out:
# Text(0.5, 1.0, 'The top films')

# %%
plt.ylabel("No. of awards")
# Out:
# Text(83.83333333333334, 0.5, 'No. of awards')

# %%
plt.xticks(range(len(new_films)), new_films)
# Out:
# ([<matplotlib.axis.XTick at 0x24dbf33e580>,
#   <matplotlib.axis.XTick at 0x24dbf33e550>,
#   <matplotlib.axis.XTick at 0x24dbf36bf40>,
#   <matplotlib.axis.XTick at 0x24dbf37b310>],
#  [Text(0, 0, 'film1'),
#   Text(1, 0, 'film2'),
#   Text(2, 0, 'film3'),
#   Text(3, 0, 'film4')])

# %%
plt.show()

# %% [markdown]
# # Pie Charts

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([37, 27, 27, 17])
ch_labels = ["first", "second", "third", "fourth"]

plt.pie(x, labels = ch_labels)
plt.show()

# %% [markdown]
# # Histograms

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
new_h = np.random.normal(150, 15, 230)

# %%
plt.hist(new_h)
plt.show()
